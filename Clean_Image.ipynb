# %%
from skimage import io
from skimage.exposure import histogram
from skimage.color import rgb2gray
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
myimg = io.imread('data/1_No_Finding/NoF_2.jpg')
myimg = rgb2gray(myimg)

# %%
plt.imshow(myimg)
plt.title('Example 1')
# Out:
# Text(0.5, 1.0, 'Example 1')

# %%
plt.imshow(myimg[:180])
plt.title('Example 2')
# Out:
# Text(0.5, 1.0, 'Example 2')

# %%
print(myimg)
# Out:
# [[0.11764706 0.11372549 0.08235294 ... 0.03529412 0.04313725 0.04705882]
#  [0.11764706 0.11372549 0.07843137 ... 0.03137255 0.03529412 0.04313725]
#  [0.11764706 0.11372549 0.0745098  ... 0.02352941 0.02745098 0.03529412]
#  ...
#  [0.67843137 0.95686275 0.9372549  ... 0.96078431 0.96862745 0.89411765]
#  [0.68235294 0.96078431 0.94901961 ... 0.96470588 0.97647059 0.89803922]
#  [0.64313725 0.90588235 0.89019608 ... 0.90196078 0.90980392 0.83921569]]
