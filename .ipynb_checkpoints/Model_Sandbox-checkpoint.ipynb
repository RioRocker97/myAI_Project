# %%
import tensorflow as tf
from tensorflow.keras import Model,layers
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint,Callback
from tensorflow.keras import metrics,optimizers
import numpy as np
from PIL import Image
from pathlib import Path
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Loading images from data
# WIN path
#PATH = "C:/Users/Lenovo/Desktop/AI/AI_Project/data/"
# Linux path
PATH = "/home/changsmarter/Desktop/myAI_Project/data_4500/"
data_dir = Path(PATH)
image_num = len(list(data_dir.glob('*/*/*.jpg')))
image_csv = pd.read_csv(PATH+'RAW_DATA_4500_6_class.csv')
CLASS_NAME = image_csv['Finding Labels'].unique()
print(image_num)
print(CLASS_NAME)
# Out:
# 22648
# ['No Finding' 'TB' 'Heart' 'CA Lung' 'Intra' 'Extra']

# %%
example_NoF = list(data_dir.glob('train/No Finding/*.jpg'))
i = 1
plt.figure(figsize=(20,20))
for n in example_NoF[:5]:
    ex = Image.open(n)
    ex_ar = np.asarray(ex)
    plt.subplot(5,5,i)
    word = "Example "+ str(i)
    plt.title(word)
    plt.imshow(ex_ar)
    i+=1

# %%
#Preproccsing image data into ImageDataGenerator
my_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
BATCH_SIZE = 32
IMG_WIDTH = 224
IMG_HEIGHT = 224
TRAIN_PATH = PATH + "/train/"
TEST_PATH = PATH + "/test/"

#This will be my train_set . 
data_gen_train = my_generator.flow_from_directory(directory=TRAIN_PATH,
                                                  batch_size=BATCH_SIZE,
                                                  shuffle=True,
                                                  target_size=(IMG_HEIGHT,IMG_WIDTH),
                                                  classes = list(CLASS_NAME))
#This will be my test_set . 
data_gen_test = my_generator.flow_from_directory(directory=TEST_PATH,
                                                 batch_size=BATCH_SIZE,
                                                 shuffle=True,
                                                 target_size=(IMG_HEIGHT,IMG_WIDTH),
                                                 classes = list(CLASS_NAME))

x_train,y_train = next(data_gen_train)
x_test,y_test = next(data_gen_test)
TRAIN_IMG = 18118
TEST_IMG = 4530
# Out:
# Found 18118 images belonging to 6 classes.
# Found 4530 images belonging to 6 classes.

# %%
plt.figure(figsize=(20,20))
for n in range(8):
    plt.subplot(4,4,n+1)
    plt.title(CLASS_NAME[y_train[n]==1][0].title())
    plt.imshow(x_train[n])

# %%
#Try to load InceptionV3
myInception = tf.keras.applications.InceptionV3(include_top=False,
                                                weights='imagenet',
                                                input_shape=(224,224,3),
                                                classes=6)
for layer in myInception.layers:
    layer.trainable = False

# %%
#Add layers configuration suitable for our model
#This is THE endgame for our project . Carefully review your stradigies 
# Current layers stacking is Awful . Inaccurate with fake accuracy

out = myInception.output
out = layers.GlobalAveragePooling2D()(out)
#out = layers.Dense(1024,activation='relu')(out)
#out = layers.Dense(512,activation='relu')(out)
#out = layers.Dense(64,activation='relu')(out)
out = layers.Dropout(0.5)(out)
out = layers.Dense(6,activation='sigmoid')(out)

myModel = Model(myInception.input,out)

# %%
#myModel.summary()

# %%
myEarly = EarlyStopping(monitor='val_loss',patience=50,verbose=1)
myCheckpoint = ModelCheckpoint('myModel_Check_7_2.hdf5',monitor='val_loss')
#Callback function when my model hit my max ACC
class mystopclass(Callback):
    def on_epoch_end(self,epoch,log={}):
        if(log.get('accuracy') > 0.99 or log.get('loss') < 0.01):
            print("\n\nReached my Destination. Stoppped Training!!\n\n")
            self.model.stop_training = True
myStop = mystopclass()

# %%
myModel.compile(loss='categorical_crossentropy',
                    optimizer=optimizers.Adam(lr=1e-4)
                ,metrics=['accuracy',metrics.AUC()])

# %%
#Try to fit data into our model
STEP_PER_EPOCH = np.ceil(TRAIN_IMG/BATCH_SIZE)
session = myModel.fit_generator(data_gen_train,
                               validation_data=data_gen_test,
                               epochs = 50,
                               steps_per_epoch=STEP_PER_EPOCH,
                               validation_steps = 30,
                               verbose = 1,
                               callbacks=[myEarly,myCheckpoint,myStop])
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 567.0 steps, validate for 30 steps
# Epoch 1/50
# 567/567 [==============================] - 56s 99ms/step - loss: 1.6535 - accuracy: 0.2126 - auc_4: 0.6091 - val_loss: 1.6523 - val_accuracy: 0.2021 - val_auc_4: 0.6144
# Epoch 2/50
# 567/567 [==============================] - 51s 89ms/step - loss: 1.6263 - accuracy: 0.2429 - auc_4: 0.6364 - val_loss: 1.6484 - val_accuracy: 0.2188 - val_auc_4: 0.6305
# Epoch 3/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.6067 - accuracy: 0.2729 - auc_4: 0.6619 - val_loss: 1.6513 - val_accuracy: 0.2479 - val_auc_4: 0.6418
# Epoch 4/50
# 567/567 [==============================] - 50s 89ms/step - loss: 1.5887 - accuracy: 0.2939 - auc_4: 0.6814 - val_loss: 1.6445 - val_accuracy: 0.2552 - val_auc_4: 0.6528
# Epoch 5/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.5728 - accuracy: 0.3154 - auc_4: 0.6946 - val_loss: 1.6378 - val_accuracy: 0.2615 - val_auc_4: 0.6573
# Epoch 6/50
# 567/567 [==============================] - 50s 89ms/step - loss: 1.5578 - accuracy: 0.3215 - auc_4: 0.7043 - val_loss: 1.6609 - val_accuracy: 0.2635 - val_auc_4: 0.6562
# Epoch 7/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.5482 - accuracy: 0.3303 - auc_4: 0.7101 - val_loss: 1.6495 - val_accuracy: 0.2698 - val_auc_4: 0.6619
# Epoch 8/50
# 567/567 [==============================] - 51s 89ms/step - loss: 1.5403 - accuracy: 0.3386 - auc_4: 0.7156 - val_loss: 1.6578 - val_accuracy: 0.2760 - val_auc_4: 0.6648
# Epoch 9/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.5328 - accuracy: 0.3434 - auc_4: 0.7191 - val_loss: 1.6627 - val_accuracy: 0.2802 - val_auc_4: 0.6632
# Epoch 10/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.5291 - accuracy: 0.3461 - auc_4: 0.7215 - val_loss: 1.6851 - val_accuracy: 0.2698 - val_auc_4: 0.6601
# Epoch 11/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.5187 - accuracy: 0.3482 - auc_4: 0.7264 - val_loss: 1.6781 - val_accuracy: 0.2865 - val_auc_4: 0.6661
# Epoch 12/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.5151 - accuracy: 0.3540 - auc_4: 0.7281 - val_loss: 1.6709 - val_accuracy: 0.2802 - val_auc_4: 0.6709
# Epoch 13/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.5102 - accuracy: 0.3606 - auc_4: 0.7306 - val_loss: 1.6688 - val_accuracy: 0.2875 - val_auc_4: 0.6717
# Epoch 14/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.5087 - accuracy: 0.3617 - auc_4: 0.7309 - val_loss: 1.6725 - val_accuracy: 0.2990 - val_auc_4: 0.6715
# Epoch 15/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.5018 - accuracy: 0.3626 - auc_4: 0.7339 - val_loss: 1.6763 - val_accuracy: 0.2875 - val_auc_4: 0.6699
# Epoch 16/50
# 567/567 [==============================] - 51s 89ms/step - loss: 1.5006 - accuracy: 0.3663 - auc_4: 0.7351 - val_loss: 1.7193 - val_accuracy: 0.2656 - val_auc_4: 0.6624
# Epoch 17/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4937 - accuracy: 0.3680 - auc_4: 0.7372 - val_loss: 1.7504 - val_accuracy: 0.2760 - val_auc_4: 0.6586
# Epoch 18/50
# 567/567 [==============================] - 50s 89ms/step - loss: 1.4920 - accuracy: 0.3706 - auc_4: 0.7387 - val_loss: 1.7047 - val_accuracy: 0.2844 - val_auc_4: 0.6683
# Epoch 19/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4876 - accuracy: 0.3734 - auc_4: 0.7400 - val_loss: 1.7309 - val_accuracy: 0.2635 - val_auc_4: 0.6633
# Epoch 20/50
# 567/567 [==============================] - 51s 89ms/step - loss: 1.4875 - accuracy: 0.3712 - auc_4: 0.7393 - val_loss: 1.6795 - val_accuracy: 0.2937 - val_auc_4: 0.6714
# Epoch 21/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4853 - accuracy: 0.3710 - auc_4: 0.7411 - val_loss: 1.7300 - val_accuracy: 0.2771 - val_auc_4: 0.6638
# Epoch 22/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4844 - accuracy: 0.3762 - auc_4: 0.7410 - val_loss: 1.7569 - val_accuracy: 0.2625 - val_auc_4: 0.6597
# Epoch 23/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4823 - accuracy: 0.3744 - auc_4: 0.7421 - val_loss: 1.7427 - val_accuracy: 0.2823 - val_auc_4: 0.6597
# Epoch 24/50
# 567/567 [==============================] - 51s 89ms/step - loss: 1.4763 - accuracy: 0.3787 - auc_4: 0.7450 - val_loss: 1.7036 - val_accuracy: 0.2896 - val_auc_4: 0.6710
# Epoch 25/50
# 567/567 [==============================] - 51s 89ms/step - loss: 1.4779 - accuracy: 0.3828 - auc_4: 0.7437 - val_loss: 1.7370 - val_accuracy: 0.2719 - val_auc_4: 0.6638
# Epoch 26/50
# 567/567 [==============================] - 51s 89ms/step - loss: 1.4782 - accuracy: 0.3763 - auc_4: 0.7432 - val_loss: 1.7097 - val_accuracy: 0.3010 - val_auc_4: 0.6681
# Epoch 27/50
# 567/567 [==============================] - 51s 89ms/step - loss: 1.4724 - accuracy: 0.3804 - auc_4: 0.7454 - val_loss: 1.7549 - val_accuracy: 0.2823 - val_auc_4: 0.6596
# Epoch 28/50
# 567/567 [==============================] - 51s 89ms/step - loss: 1.4731 - accuracy: 0.3788 - auc_4: 0.7456 - val_loss: 1.7354 - val_accuracy: 0.2656 - val_auc_4: 0.6643
# Epoch 29/50
# 567/567 [==============================] - 50s 89ms/step - loss: 1.4705 - accuracy: 0.3808 - auc_4: 0.7466 - val_loss: 1.7584 - val_accuracy: 0.3031 - val_auc_4: 0.6641
# Epoch 30/50
# 567/567 [==============================] - 50s 89ms/step - loss: 1.4729 - accuracy: 0.3758 - auc_4: 0.7452 - val_loss: 1.7269 - val_accuracy: 0.2896 - val_auc_4: 0.6656
# Epoch 31/50
# 567/567 [==============================] - 50s 89ms/step - loss: 1.4758 - accuracy: 0.3750 - auc_4: 0.7438 - val_loss: 1.7244 - val_accuracy: 0.3010 - val_auc_4: 0.6679
# Epoch 32/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4683 - accuracy: 0.3819 - auc_4: 0.7477 - val_loss: 1.7480 - val_accuracy: 0.2688 - val_auc_4: 0.6619
# Epoch 33/50
# 567/567 [==============================] - 51s 89ms/step - loss: 1.4656 - accuracy: 0.3849 - auc_4: 0.7482 - val_loss: 1.7318 - val_accuracy: 0.2688 - val_auc_4: 0.6669
# Epoch 34/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4658 - accuracy: 0.3846 - auc_4: 0.7478 - val_loss: 1.7352 - val_accuracy: 0.2792 - val_auc_4: 0.6672
# Epoch 35/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4662 - accuracy: 0.3853 - auc_4: 0.7474 - val_loss: 1.7258 - val_accuracy: 0.2865 - val_auc_4: 0.6679
# Epoch 36/50
# 567/567 [==============================] - 51s 89ms/step - loss: 1.4630 - accuracy: 0.3869 - auc_4: 0.7485 - val_loss: 1.7709 - val_accuracy: 0.2594 - val_auc_4: 0.6601
# Epoch 37/50
# 567/567 [==============================] - 51s 89ms/step - loss: 1.4606 - accuracy: 0.3803 - auc_4: 0.7491 - val_loss: 1.7550 - val_accuracy: 0.2833 - val_auc_4: 0.6654
# Epoch 38/50
# 567/567 [==============================] - 51s 89ms/step - loss: 1.4623 - accuracy: 0.3861 - auc_4: 0.7492 - val_loss: 1.7234 - val_accuracy: 0.2990 - val_auc_4: 0.6694
# Epoch 39/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4621 - accuracy: 0.3909 - auc_4: 0.7492 - val_loss: 1.7478 - val_accuracy: 0.2802 - val_auc_4: 0.6647
# Epoch 40/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4614 - accuracy: 0.3877 - auc_4: 0.7489 - val_loss: 1.7542 - val_accuracy: 0.2688 - val_auc_4: 0.6624
# Epoch 41/50
# 567/567 [==============================] - 50s 89ms/step - loss: 1.4617 - accuracy: 0.3891 - auc_4: 0.7493 - val_loss: 1.7598 - val_accuracy: 0.2667 - val_auc_4: 0.6624
# Epoch 42/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4583 - accuracy: 0.3891 - auc_4: 0.7504 - val_loss: 1.7825 - val_accuracy: 0.2740 - val_auc_4: 0.6613
# Epoch 43/50
# 567/567 [==============================] - 51s 89ms/step - loss: 1.4568 - accuracy: 0.3898 - auc_4: 0.7510 - val_loss: 1.7617 - val_accuracy: 0.2937 - val_auc_4: 0.6650
# Epoch 44/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4645 - accuracy: 0.3805 - auc_4: 0.7472 - val_loss: 1.7338 - val_accuracy: 0.2781 - val_auc_4: 0.6639
# Epoch 45/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4584 - accuracy: 0.3897 - auc_4: 0.7500 - val_loss: 1.7932 - val_accuracy: 0.2823 - val_auc_4: 0.6583
# Epoch 46/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4565 - accuracy: 0.3859 - auc_4: 0.7497 - val_loss: 1.7401 - val_accuracy: 0.3010 - val_auc_4: 0.6653
# Epoch 47/50
# 567/567 [==============================] - 50s 89ms/step - loss: 1.4590 - accuracy: 0.3876 - auc_4: 0.7490 - val_loss: 1.7593 - val_accuracy: 0.2760 - val_auc_4: 0.6603
# Epoch 48/50
# 567/567 [==============================] - 51s 89ms/step - loss: 1.4565 - accuracy: 0.3843 - auc_4: 0.7500 - val_loss: 1.8130 - val_accuracy: 0.2969 - val_auc_4: 0.6602
# Epoch 49/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4532 - accuracy: 0.3888 - auc_4: 0.7514 - val_loss: 1.7643 - val_accuracy: 0.2906 - val_auc_4: 0.6643
# Epoch 50/50
# 567/567 [==============================] - 51s 90ms/step - loss: 1.4538 - accuracy: 0.3926 - auc_4: 0.7513 - val_loss: 1.7596 - val_accuracy: 0.2812 - val_auc_4: 0.6640

# %%
plt.figure(figsize=(5,5))
plt.plot(session.history['accuracy'])
plt.plot(session.history['val_accuracy'])
plt.title('Accuracy')
plt.ylabel('Value')
plt.xlabel('Iterations')
plt.legend(['Train','Test'])
plt.savefig("7th_Run_Accuracy.png")
plt.show()
plt.figure(figsize=(5,5))
plt.plot(session.history['loss'])
plt.plot(session.history['val_loss'])
plt.title('Loss')
plt.ylabel('Value')
plt.xlabel('Iterations')
plt.legend(['Train','Test'])
plt.savefig("7th_Run_Loss.png")
plt.show()

# %%
from sklearn.metrics import confusion_matrix,f1_score
y_res = myModel.predict(x_test)
y_pred = np.argmax(y_res,axis=1)
y_true = np.argmax(y_test,axis=1)
myCM = confusion_matrix(y_true,y_pred)
myCM_Nor = myCM.astype('float')/myCM.sum(axis=1)[:,np.newaxis]
print(myCM)
print(myCM_Nor)
# Out:
# [[3 1 1 0 2]
#  [3 0 1 0 3]
#  [6 0 2 0 0]
#  [2 0 2 0 1]
#  [4 0 0 0 1]]
# [[0.42857143 0.14285714 0.14285714 0.         0.28571429]
#  [0.42857143 0.         0.14285714 0.         0.42857143]
#  [0.75       0.         0.25       0.         0.        ]
#  [0.4        0.         0.4        0.         0.2       ]
#  [0.8        0.         0.         0.         0.2       ]]

# %%
#7th run CM is lost one class !!!WTF
y_test.shape
# Out:
# (32, 6)

# %%
import seaborn as sn
import pandas as pd

cm_plot = pd.DataFrame(myCM,CLASS_NAME[:5],CLASS_NAME[:5])
sn.set(font_scale=1.6)
plt.figure(figsize=(10,10))
plt.title("7th Run Confusion Matrix")
cm= sn.heatmap(cm_plot,annot=True,annot_kws={"size":18},cmap="Blues")
cm = cm.get_figure()
cm.savefig('7th_run_CM.png')
plt.show()

# %%
cm_plot = pd.DataFrame(myCM_Nor,CLASS_NAME[:5],CLASS_NAME[:5])
sn.set(font_scale=1.6)
plt.figure(figsize=(10,10))
plt.title("7th Run Normalized Confusion Matrix ")
cm= sn.heatmap(cm_plot,annot=True,annot_kws={"size":18},cmap="Blues")
cm = cm.get_figure()
cm.savefig('7th_run_CM_nor.png')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(session.history['auc_4'])
plt.plot(session.history['val_auc_4'])
plt.title("7th Run ROC curve")
plt.legend({'Train Baseline','Test Baseline'})
plt.ylabel('Score')
plt.xlabel('Iterations')
plt.savefig("7th_Run_ROC.png")
plt.show()
