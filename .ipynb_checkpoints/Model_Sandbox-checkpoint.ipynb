# %%
import tensorflow as tf
from tensorflow.keras import Model,layers
import numpy as np
from PIL import Image
from pathlib import Path
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Loading images from data
# WIN path
# PATH = "C:/Users/Lenovo/Desktop/AI/AI_Project/data/"
# Linux path
PATH = "/home/changsmarter/Desktop/myAI_Project/data/"
data_dir = Path(PATH)
image_num = len(list(data_dir.glob('*/*/*.jpg')))

# %%
image_num
# Out:
# 5110

# %%
image_csv = pd.read_csv(PATH+'Raw_Data_JPG.csv')
CLASS_NAME = image_csv.Diagnosis.unique()

# %%
CLASS_NAME
# Out:
# array(['No Finding', 'TB', 'Heart', 'CA lung', 'Intra', 'Extra'],
#       dtype=object)

# %%
example_NoF = list(data_dir.glob('train/No Finding/*.jpg'))
i = 1
plt.figure(figsize=(20,20))
for n in example_NoF[:5]:
    ex = Image.open(n)
    ex_ar = np.asarray(ex)
    plt.subplot(5,5,i)
    word = "Example "+ str(i)
    plt.title(word)
    plt.imshow(ex_ar)
    i+=1

# %%
#Preproccsing image data into ImageDataGenerator
my_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
BATCH_SIZE = 32
IMG_WIDTH = 224
IMG_HEIGHT = 224
STEP_PER_EPOCH = np.ceil(4088/BATCH_SIZE)

TRAIN_PATH = PATH + "/train/"
TEST_PATH = PATH + "/test/"

# %%
#This will be my train_set . 
data_gen_train = my_generator.flow_from_directory(directory=TRAIN_PATH,batch_size=BATCH_SIZE,shuffle=True,target_size=(IMG_HEIGHT,IMG_WIDTH),classes = list(CLASS_NAME))
# Out:
# Found 4088 images belonging to 6 classes.

# %%
img_batch,label_batch = next(data_gen_train)

# %%
data_gen_test = my_generator.flow_from_directory(directory=TEST_PATH,batch_size=BATCH_SIZE,shuffle=True,target_size=(IMG_HEIGHT,IMG_WIDTH),classes = list(CLASS_NAME))
# Out:
# Found 1022 images belonging to 6 classes.

# %%
img_batch_test,label_batch_test = next(data_gen_test)

# %%
plt.figure(figsize=(20,20))
for n in range(8):
    plt.subplot(4,4,n+1)
    plt.title(CLASS_NAME[label_batch[n]==1][0].title())
    plt.imshow(img_batch[n])

# %%
#label_batch_test

# %%
#Try to load InceptionV3
myInception = tf.keras.applications.InceptionV3(include_top=False,weights='imagenet',input_shape=(224,224,3),classes=6)

# %%
for layer in myInception.layers:
    layer.trainable = False

# %%
out = layers.Flatten()(myInception.output)
out = layers.Dense(1024,activation='relu')(out)
out = layers.Dropout(0.2)(out)
out = layers.Dense(1,activation='sigmoid')(out)

myModel = Model(myInception.input,out)

# %%
#myInception.summary()
myModel.compile(loss='categorical_crossentropy',
                    optimizer='adam',metrics=['accuracy'])

# %%
#Try to fit data into our model
session = myModel.fit_generator(data_gen_train,
                               validation_data=data_gen_test,
                               steps_per_epoch = STEP_PER_EPOCH,
                               epochs = 100,
                               validation_steps = 20,
                               verbose = 1,)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 128.0 steps, validate for 20 steps
# Epoch 1/100
# 128/128 [==============================] - 14s 112ms/step - loss: 1.1921e-07 - accuracy: 0.4286 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 2/100
# 128/128 [==============================] - 13s 105ms/step - loss: 1.1921e-07 - accuracy: 0.4320 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 3/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4269 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 4/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4289 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 5/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4310 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 6/100
# 128/128 [==============================] - 13s 102ms/step - loss: 1.1921e-07 - accuracy: 0.4274 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 7/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4307 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 8/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4261 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 9/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4315 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 10/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4338 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 11/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4309 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 12/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4269 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 13/100
# 128/128 [==============================] - 13s 102ms/step - loss: 1.1921e-07 - accuracy: 0.4357 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 14/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4286 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 15/100
# 128/128 [==============================] - 13s 102ms/step - loss: 1.1921e-07 - accuracy: 0.4317 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 16/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4232 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 17/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4313 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 18/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4320 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 19/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4313 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 20/100
# 128/128 [==============================] - 13s 102ms/step - loss: 1.1921e-07 - accuracy: 0.4260 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 21/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4323 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 22/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4278 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 23/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4242 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 24/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4278 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 25/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4281 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 26/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4289 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 27/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4295 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 28/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4227 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 29/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4315 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 30/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4299 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 31/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4338 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 32/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4302 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 33/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4242 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 34/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4304 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 35/100
# 128/128 [==============================] - 13s 105ms/step - loss: 1.1921e-07 - accuracy: 0.4216 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 36/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4305 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 37/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4271 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 38/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4307 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 39/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4261 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 40/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4296 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 41/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4312 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 42/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4255 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 43/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4323 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 44/100
# 128/128 [==============================] - 13s 105ms/step - loss: 1.1921e-07 - accuracy: 0.4317 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 45/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4294 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 46/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4343 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 47/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4318 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 48/100
# 128/128 [==============================] - 14s 106ms/step - loss: 1.1921e-07 - accuracy: 0.4323 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 49/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4385 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 50/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4240 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 51/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4348 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 52/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4282 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 53/100
# 128/128 [==============================] - 13s 102ms/step - loss: 1.1921e-07 - accuracy: 0.4294 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 54/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4341 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 55/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4357 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 56/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4317 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 57/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4328 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 58/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4330 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 59/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4302 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 60/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4256 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 61/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4323 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 62/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4289 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 63/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4335 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 64/100
# 128/128 [==============================] - 13s 105ms/step - loss: 1.1921e-07 - accuracy: 0.4341 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 65/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4284 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 66/100
# 128/128 [==============================] - 13s 105ms/step - loss: 1.1921e-07 - accuracy: 0.4279 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 67/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4229 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 68/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4423 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 69/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4216 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 70/100
# 128/128 [==============================] - 13s 105ms/step - loss: 1.1921e-07 - accuracy: 0.4357 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 71/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4330 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 72/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4294 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 73/100
# 128/128 [==============================] - 13s 105ms/step - loss: 1.1921e-07 - accuracy: 0.4253 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 74/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4315 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 75/100
# 128/128 [==============================] - 13s 105ms/step - loss: 1.1921e-07 - accuracy: 0.4411 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 76/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4281 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 77/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4273 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 78/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4256 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 79/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4305 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 80/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4307 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 81/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4331 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 82/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4289 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 83/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4340 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 84/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4304 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 85/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4336 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 86/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4362 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 87/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4282 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 88/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4266 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 89/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4348 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 90/100
# 128/128 [==============================] - 13s 105ms/step - loss: 1.1921e-07 - accuracy: 0.4344 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 91/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4291 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 92/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4336 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 93/100
# 128/128 [==============================] - 13s 103ms/step - loss: 1.1921e-07 - accuracy: 0.4302 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 94/100
# 128/128 [==============================] - 13s 105ms/step - loss: 1.1921e-07 - accuracy: 0.4317 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 95/100
# 128/128 [==============================] - 13s 102ms/step - loss: 1.1921e-07 - accuracy: 0.4312 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 96/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4284 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 97/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4281 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 98/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4292 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 99/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4310 - val_loss: 1.1921e-07 - val_accuracy: 0.3813
# Epoch 100/100
# 128/128 [==============================] - 13s 104ms/step - loss: 1.1921e-07 - accuracy: 0.4279 - val_loss: 1.1921e-07 - val_accuracy: 0.3813

# %%
plt.figure(figsize=(10,10))
plt.plot(session.history['accuracy'])
plt.plot(session.history['loss'])
plt.title('Accuracy & Loss')
plt.ylabel('Value')
plt.xlabel('Epoch')
plt.legend(['Accuracy','Loss'])
plt.show()

# %%
test_session = myModel.predict_generator(data_gen_test,np.ceil(1022/32))

# %%
num = 0
for i in range(0,test_session.size):
    if(test_session[i] > 0.8):
        num+=1
num
# Out:
# 82
