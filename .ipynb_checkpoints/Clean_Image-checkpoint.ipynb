# %%
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from PIL import ImageOps

# %%
PATH = './data/1_No_Finding/'

# %%
myimg = Image.open(PATH+'NoF_98.jpg')

# %%
myimg = ImageOps.grayscale(myimg)

# %%
myimg_ar = np.asarray(myimg)

# %%
print(myimg_ar.shape)
# Out:
# (224, 224)

# %%
print(myimg_ar)
# Out:
# [[ 37  36  35 ...  95  97  99]
#  [ 36  34  34 ...  48  49  51]
#  [ 35  33  32 ...  29  30  31]
#  ...
#  [ 18  16  15 ... 158 150 141]
#  [ 18  16  15 ... 164 157 148]
#  [ 18  16  15 ... 166 160 154]]

# %%
plt.imshow(myimg_ar[:200][:224])

# %%
#for i range(0,244):
#    for j in range(0,244):
# Out:
# 161
# 161
